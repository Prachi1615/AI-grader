# %%
# %pip install --upgrade --quiet  boto3
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.2.4-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting langchain<0.3.0,>=0.2.0 (from langchain-community)
#   Downloading langchain-0.2.4-py3-none-any.whl.metadata (7.0 kB)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain-community)
#   Downloading langchain_core-0.2.7-py3-none-any.whl.metadata (5.8 kB)
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-community)
#   Downloading langsmith-0.1.77-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy<2,>=1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-community) (1.26.3)
# Requirement already satisfied: requests<3,>=2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-community) (2.31.0)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain-community)
#   Using cached tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.0->langchain-community)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pydantic<3,>=1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (2.5.0)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain-community)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (23.2)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain-community)
#   Downloading orjson-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain-community) (2022.12.7)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.14.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (2.14.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_community-0.2.4-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.1 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain-0.2.4-py3-none-any.whl (974 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.2/974.2 kB 20.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading langchain_core-0.2.7-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.6/315.6 kB 23.5 MB/s eta 0:00:00
# Downloading langsmith-0.1.77-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 37.8 MB/s eta 0:00:00
# Using cached tenacity-8.3.0-py3-none-any.whl (25 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 21.5 MB/s eta 0:00:00
# Downloading orjson-3.10.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 37.8 MB/s eta 0:00:00
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, orjson, mypy-extensions, marshmallow, jsonpatch, typing-inspect, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain, langchain-community
# Successfully installed dataclasses-json-0.6.7 jsonpatch-1.33 langchain-0.2.4 langchain-community-0.2.4 langchain-core-0.2.7 langchain-text-splitters-0.2.1 langsmith-0.1.77 marshmallow-3.21.3 mypy-extensions-1.0.0 orjson-3.10.5 tenacity-8.3.0 typing-inspect-0.9.0
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install langchain==0.1.17
# !pip install langchain-anthropic
# !pip install boto3==1.34.95
# !pip install faiss-cpu==1.8.0
# Out:
# Collecting langchain==0.1.17
#   Downloading langchain-0.1.17-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (1.33)
# Collecting langchain-community<0.1,>=0.0.36 (from langchain==0.1.17)
#   Downloading langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.48 (from langchain==0.1.17)
#   Downloading langchain_core-0.1.52-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain==0.1.17)
#   Downloading langchain_text_splitters-0.0.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (1.26.3)
# Requirement already satisfied: pydantic<3,>=1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (2.5.0)
# Requirement already satisfied: requests<3,>=2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain==0.1.17) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-core<0.2.0,>=0.1.48->langchain==0.1.17) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.10.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from pydantic<3,>=1->langchain==0.1.17) (0.7.0)
# Requirement already satisfied: pydantic-core==2.14.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from pydantic<3,>=1->langchain==0.1.17) (2.14.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from pydantic<3,>=1->langchain==0.1.17) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.1.17) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.1.17) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.1.17) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.1.17) (2022.12.7)
# Requirement already satisfied: greenlet!=0.4.17 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (1.0.0)
# Downloading langchain-0.1.17-py3-none-any.whl (867 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.6/867.6 kB 21.9 MB/s eta 0:00:0031m21.5 MB/s eta 0:00:01
# Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 84.3 MB/s eta 0:00:00
# Downloading langchain_core-0.1.52-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 106.4 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.0.2-py3-none-any.whl (23 kB)
# Installing collected packages: langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.7
#     Uninstalling langchain-core-0.2.7:
#       Successfully uninstalled langchain-core-0.2.7
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.2.1
#     Uninstalling langchain-text-splitters-0.2.1:
#       Successfully uninstalled langchain-text-splitters-0.2.1
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.2.4
#     Uninstalling langchain-community-0.2.4:
#       Successfully uninstalled langchain-community-0.2.4
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.2.4
#     Uninstalling langchain-0.2.4:
#       Successfully uninstalled langchain-0.2.4
# Successfully installed langchain-0.1.17 langchain-community-0.0.38 langchain-core-0.1.52 langchain-text-splitters-0.0.2
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-0.1.15-py3-none-any.whl.metadata (2.1 kB)
# Collecting anthropic<1,>=0.28.0 (from langchain-anthropic)
#   Downloading anthropic-0.28.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-anthropic) (0.7.1)
# Collecting langchain-core<0.3,>=0.2.2rc1 (from langchain-anthropic)
#   Using cached langchain_core-0.2.7-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anthropic<1,>=0.28.0->langchain-anthropic) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anthropic<1,>=0.28.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anthropic<1,>=0.28.0->langchain-anthropic) (0.26.0)
# Collecting jiter<1,>=0.4.0 (from anthropic<1,>=0.28.0->langchain-anthropic)
#   Downloading jiter-0.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anthropic<1,>=0.28.0->langchain-anthropic) (2.5.0)
# Requirement already satisfied: sniffio in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anthropic<1,>=0.28.0->langchain-anthropic) (1.3.0)
# Requirement already satisfied: tokenizers>=0.13.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anthropic<1,>=0.28.0->langchain-anthropic) (0.19.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anthropic<1,>=0.28.0->langchain-anthropic) (4.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (0.1.77)
# Requirement already satisfied: packaging<25,>=23.2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (23.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (8.3.0)
# Requirement already satisfied: idna>=2.8 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.28.0->langchain-anthropic) (3.4)
# Requirement already satisfied: certifi in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.28.0->langchain-anthropic) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->anthropic<1,>=0.28.0->langchain-anthropic) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic<1,>=0.28.0->langchain-anthropic) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (3.10.5)
# Requirement already satisfied: requests<3,>=2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (2.31.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic<1,>=0.28.0->langchain-anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.14.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->anthropic<1,>=0.28.0->langchain-anthropic) (2.14.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from tokenizers>=0.13.0->anthropic<1,>=0.28.0->langchain-anthropic) (0.23.2)
# Requirement already satisfied: filelock in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.28.0->langchain-anthropic) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.28.0->langchain-anthropic) (2023.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.28.0->langchain-anthropic) (4.66.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core<0.3,>=0.2.2rc1->langchain-anthropic) (1.26.13)
# Downloading langchain_anthropic-0.1.15-py3-none-any.whl (16 kB)
# Downloading anthropic-0.28.1-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.7/862.7 kB 23.0 MB/s eta 0:00:00m eta 0:00:01
# Using cached langchain_core-0.2.7-py3-none-any.whl (315 kB)
# Downloading jiter-0.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.5/327.5 kB 109.3 MB/s eta 0:00:00
# Installing collected packages: jiter, langchain-core, anthropic, langchain-anthropic
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.1.52
#     Uninstalling langchain-core-0.1.52:
#       Successfully uninstalled langchain-core-0.1.52
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-community 0.0.38 requires langchain-core<0.2.0,>=0.1.52, but you have langchain-core 0.2.7 which is incompatible.
# langchain 0.1.17 requires langchain-core<0.2.0,>=0.1.48, but you have langchain-core 0.2.7 which is incompatible.
# Successfully installed anthropic-0.28.1 jiter-0.4.2 langchain-anthropic-0.1.15 langchain-core-0.2.7
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting boto3==1.34.95
#   Downloading boto3-1.34.95-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: botocore<1.35.0,>=1.34.95 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from boto3==1.34.95) (1.34.127)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from boto3==1.34.95) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from boto3==1.34.95) (0.10.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.95->boto3==1.34.95) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.95->boto3==1.34.95) (1.26.13)
# Requirement already satisfied: six>=1.5 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.95->boto3==1.34.95) (1.16.0)
# Downloading boto3-1.34.95-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: boto3
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.34.127
#     Uninstalling boto3-1.34.127:
#       Successfully uninstalled boto3-1.34.127
# Successfully installed boto3-1.34.95
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Collecting faiss-cpu==1.8.0
#   Downloading faiss_cpu-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from faiss-cpu==1.8.0) (1.26.3)
# Downloading faiss_cpu-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 78.4 MB/s eta 0:00:000m eta 0:00:010:0101
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install boto3 awscli
# Out:
# Requirement already satisfied: boto3 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (1.34.95)
# Collecting awscli
#   Downloading awscli-1.33.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: botocore<1.35.0,>=1.34.95 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from boto3) (1.34.127)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from boto3) (0.10.1)
# Collecting docutils<0.17,>=0.10 (from awscli)
#   Downloading docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from awscli) (6.0.1)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.95->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from botocore<1.35.0,>=1.34.95->boto3) (1.26.13)
# Collecting pyasn1>=0.1.3 (from rsa<4.8,>=3.1.2->awscli)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: six>=1.5 in /home/snoronha/projects/gpt_implementation/env/lib/python3.11/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.95->boto3) (1.16.0)
# Downloading awscli-1.33.9-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 54.3 MB/s eta 0:00:0031m60.2 MB/s eta 0:00:01
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 125.5 MB/s eta 0:00:00
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: pyasn1, docutils, colorama, rsa, awscli
# Successfully installed awscli-1.33.9 colorama-0.4.6 docutils-0.16 pyasn1-0.6.0 rsa-4.7.2
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# {
#     "UserId": "AROA54O42QPXNR5RPIGS3:Participant",
#     "Account": "954482721774",
#     "Arn": "arn:aws:sts::954482721774:assumed-role/WSParticipantRole/Participant"
# }

# %%
import os
from typing import Optional

# External Dependencies:
import boto3
from botocore.config import Config


def get_bedrock_client(assumed_role: Optional[str] = None, region: Optional[str] = 'us-east-1',runtime: Optional[bool] = True,external_id=None, ep_url=None):
    """Create a boto3 client for Amazon Bedrock, with optional configuration overrides 
    """
    target_region = region

    print(f"Create new client\n  Using region: {target_region}:external_id={external_id}: ")
    session_kwargs = {"region_name": target_region}
    client_kwargs = {**session_kwargs}

    profile_name = os.environ.get("AWS_PROFILE")
    if profile_name:
        print(f"  Using profile: {profile_name}")
        session_kwargs["profile_name"] = profile_name

    retry_config = Config(
        region_name=target_region,
        retries={
            "max_attempts": 10,
            "mode": "standard",
        },
    )
    session = boto3.Session(**session_kwargs)

    if assumed_role:
        print(f"  Using role: {assumed_role}", end='')
        sts = session.client("sts")
        if external_id:
            response = sts.assume_role(
                RoleArn=str(assumed_role),
                RoleSessionName="langchain-llm-1",
                ExternalId=external_id
            )
        else:
            response = sts.assume_role(
                RoleArn=str(assumed_role),
                RoleSessionName="langchain-llm-1",
            )
        print(f"Using role: {assumed_role} ... sts::successful!")
        client_kwargs["aws_access_key_id"] = response["Credentials"]["AccessKeyId"]
        client_kwargs["aws_secret_access_key"] = response["Credentials"]["SecretAccessKey"]
        client_kwargs["aws_session_token"] = response["Credentials"]["SessionToken"]

    if runtime:
        service_name='bedrock-runtime'
    else:
        service_name='bedrock'

    if ep_url:
        bedrock_client = session.client(service_name=service_name,config=retry_config,endpoint_url = ep_url, **client_kwargs )
    else:
        bedrock_client = session.client(service_name=service_name,config=retry_config, **client_kwargs )

    print("boto3 Bedrock client successfully created!")
    print(bedrock_client._endpoint)
    return bedrock_client

# %%
import json
import os
import sys

import boto3
import botocore



# ---- ⚠️ Un-comment and edit the below lines as needed for your AWS setup ⚠️ ----
bedrock_runtime = get_bedrock_client() 
# os.environ["AWS_DEFAULT_REGION"] = "<REGION_NAME>"  # E.g. "us-east-1"
# os.environ["AWS_PROFILE"] = "<YOUR_PROFILE>"
# os.environ["BEDROCK_ASSUME_ROLE"] = "<YOUR_ROLE_ARN>"  # E.g. "arn:aws:..."
# Out:
# Create new client
#   Using region: us-east-1:external_id=None:
# boto3 Bedrock client successfully created!
# bedrock-runtime(https://bedrock-runtime.us-east-1.amazonaws.com)

# %%
bedrock_runtime

# %%
from io import StringIO
import sys
import textwrap
from langchain.llms.bedrock import Bedrock
from typing import Optional, List, Any
from langchain.callbacks.manager import CallbackManagerForLLMRun

def print_ww(*args, width: int = 100, **kwargs):
    """Like print(), but wraps output to `width` characters (default 100)"""
    buffer = StringIO()
    try:
        _stdout = sys.stdout
        sys.stdout = buffer
        print(*args, **kwargs)
        output = buffer.getvalue()
    finally:
        sys.stdout = _stdout
    for line in output.splitlines():
        print("\n".join(textwrap.wrap(line, width=width)))

# %%
import json 
modelId = "anthropic.claude-3-sonnet-20240229-v1:0" #"anthropic.claude-v2"

messages=[
    { 
        "role":'user', 
        "content":[{
            'type':'text',
            'text': "What is quantum mechanics? "
        }]
    },
    { 
        "role":'assistant', 
        "content":[{
            'type':'text',
            'text': "It is a branch of physics that describes how matter and energy interact with discrete energy values "
        }]
    },
    { 
        "role":'user', 
        "content":[{
            'type':'text',
            'text': "Can you explain a bit more about discrete energies?"
        }]
    }
]
body=json.dumps(
        {
            "anthropic_version": "bedrock-2023-05-31",
            "max_tokens": 100,
            "messages": messages,
            "temperature": 0.5,
            "top_p": 0.9
        }  
    )  
    
response = bedrock_runtime.invoke_model(body=body, modelId=modelId)
response_body = json.loads(response.get('body').read())
print_ww(response_body)
# Out:
# ---------------------------------------------------------------------------
# AccessDeniedException                     Traceback (most recent call last)
# Cell In[19], line 37
#       4 messages=[
#       5     {
#       6         "role":'user',
#    (...)
#      25     }
#      26 ]
#      27 body=json.dumps(
#      28         {
#      29             "anthropic_version": "bedrock-2023-05-31",
#    (...)
#      34         }
#      35     )
# ---> 37 response = bedrock_runtime.invoke_model(body=body, modelId=modelId)
#      38 response_body = json.loads(response.get('body').read())
#      39 print_ww(response_body)
#
# File ~/projects/gpt_implementation/env/lib/python3.11/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/projects/gpt_implementation/env/lib/python3.11/site-packages/botocore/client.py:1021, in BaseClient._make_api_call(self, operation_name, api_params)
#    1017     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1018         "Code"
#    1019     )
#    1020     error_class = self.exceptions.from_code(error_code)
# -> 1021     raise error_class(parsed_response, operation_name)
#    1022 else:
#    1023     return parsed_response
#
# AccessDeniedException: An error occurred (AccessDeniedException) when calling the InvokeModel operation: User: arn:aws:sts::954482721774:assumed-role/WSParticipantRole/Participant is not authorized to perform: bedrock:InvokeModel on resource: arn:aws:bedrock:us-east-1::foundation-model/anthropic.claude-3-sonnet-20240229-v1:0 with an explicit deny in a service control policy

# %%
# !pip freeze>requirements.txt
